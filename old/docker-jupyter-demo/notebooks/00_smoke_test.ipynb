# %%
import sys, platform
print(platform.python_version())
print(sys.executable)
# Out:
# 3.12.7
# /opt/conda/bin/python

# %%
import pandas as pd
import numpy as np
pd.DataFrame({"x": np.arange(5), "y": np.arange(5)**2})
# Out:
#    x   y
# 0  0   0
# 1  1   1
# 2  2   4
# 3  3   9
# 4  4  16

# %%
#tâche 1 : Créer un csv
import pandas as pd
import numpy as np

df = pd.DataFrame({"produit": ["A", "B", "C"], "ventes": [100, 200, 150]})
df.to_csv("/opt/notebooks/sales.csv", index=False)
print("CSV sauvegardé !")
# Out:
# CSV sauvegardé !

# %%
#tâche 2 : Faire un graphique
import matplotlib.pyplot as plt

df.plot(x="produit", y="ventes", kind="bar", color="purple")
plt.show()

# %%
#tâche 3: vérifier les versions
import pandas as pd, sys
print(sys.version)
print(pd.__version__)
# Out:
# 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:02) [GCC 11.2.0]
# 2.2.2

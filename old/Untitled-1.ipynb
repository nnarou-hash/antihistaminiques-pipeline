# %%
import pandas as pd
import math

# %%
fb = pd.read_excel("/Users/nellyta/Downloads/jedha ex/Hours Spent on Facebook.xlsx")
print(fb.shape)
# Out:
# (102, 2)

# %%
fb.head()
# Out:
#    Customer   Hours spent on Facebook on Mobile
# 0          1                           4.092475
# 1          2                           7.233371
# 2          3                           7.455792
# 3          4                           7.253503
# 4          5                           2.249682

# %%
mean_fb = fb.mean()

# %%
stb_fb = fb.std

# %%
t = 1.96

# %%
fb.describe()
# Out:
#         Customer   Hours spent on Facebook on Mobile
# count  102.000000                         102.000000
# mean    51.500000                           4.847316
# std     29.588849                           2.978913
# min      1.000000                           0.034569
# 25%     26.250000                           2.300628
# 50%     51.500000                           4.896723
# 75%     76.750000                           7.529681
# max    102.000000                           9.969544

# %%
n_fb = len(fb)

# %%
E = t * stb_fb / sqrt
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/fr/d72906vd54q6gg50m9cxf9bw0000gn/T/ipykernel_41724/4233418094.py in <module>
# ----> 1 t * stb_fb / sqrt(n_fb)
#
# TypeError: unsupported operand type(s) for *: 'float' and 'method'

# %%
gl = pd.read_excel("/Users/nellyta/Downloads/jedha ex/Monthly spending on adwords.xlsx")
print (gl.shape)
# Out:
# (31, 1)
